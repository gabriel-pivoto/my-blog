# %% [markdown]
# ---
# title: 'Statistics'
# description: 'Measures of Position, Dispersion, and Shape'
# pubDate: 'Nov 14 2025'
# ---

# %% [markdown]
# I use pandas to analysis

# %% [markdown]
# Import the library

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# Create a dictionary for analysis

# %%
dict_data = {'age': [12, 13, 65, 43, 23, 44, 33, 12, 54, 32, 23], 'height': [1.2, 1.3, 1.65, 1.43, 2.3, 1.44, 1.33, 1.2, 1.54, 1.32, 2.3]}
dict_data
# Out:
# {'age': [12, 13, 65, 43, 23, 44, 33, 12, 54, 32, 23],
#  'height': [1.2, 1.3, 1.65, 1.43, 2.3, 1.44, 1.33, 1.2, 1.54, 1.32, 2.3]}

# %% [markdown]
# after that, create a DataFrame from the dictionary and display descriptive data

# %%
df_data = pd.DataFrame(dict_data)
df_data.describe()
# Out:
#              age     height
# count  11.000000  11.000000
# mean   32.181818   1.546364
# std    17.780991   0.396264
# min    12.000000   1.200000
# 25%    18.000000   1.310000
# 50%    32.000000   1.430000
# 75%    43.500000   1.595000
# max    65.000000   2.300000
